# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs

# %%
# Activation Function
def activation(X):
    if X > 0:
        return(1)
    elif X <= 0: 
        return(0)

# Perceptron Model
def perceptron(X, labels, r, n_epochs):
    # Binary Classification with Perceptron
    
    
    w = np.zeros(X.shape[1])
    output = np.zeros(len(labels))

    n = 0
    while n < n_epochs:
        for j in range(len(labels)):
            
            # Get Output of Using Current Weights
            output[j] = activation(np.dot(w, X[j, :]))
            
            # Update Weights
            w += r * (y[j] - output[j]) * X[j, :]
        n += 1
    return(w)

# %%
# Simulate Data
centers = [[1, 1], [2, 2]]
X, y = make_blobs(n_samples = 10**3, centers = centers, cluster_std = 0.2)
plt.scatter(X[:, 0], X[:, 1])
plt.scatter(X[:, 0], X[:, 1], c = y)

# %%
# Adjust Data Matrix to Account for Bias Term
X_w_bias = np.hstack((X, np.ones((X.shape[0], 1))))

# Create Perceptron Model and Return Weights
w = perceptron(X_w_bias, y, r = 0.001, n_epochs = 100)

# Get Predictions Using Activation Function
predict = np.zeros(len(y))
for i in range(len(y)):
    predict[i] = activation(np.dot(w, X_w_bias[i, :]))
    
# Plot Predictions
plt.scatter(X[:, 0], X[:, 1], c = predict)
